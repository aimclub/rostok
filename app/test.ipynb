# %%
import rule_extention

# %%
rule_vocabul, node_features = rule_extention.init_extension_rules()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 rule_vocabul, node_features = rule_extention.init_extension_rules()
#
# NameError: name 'rule_extention' is not defined
