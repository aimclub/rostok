# %%
from rostok.utils.result_saver import MCTSReporter, load_reporter
from pathlib import Path

reporter:MCTSReporter = load_reporter(Path(r"E:\work\projects\rostok\results\MCTS_report_23y_01m_13d_20H_01M"))

# %%
reporter.plot_means()
